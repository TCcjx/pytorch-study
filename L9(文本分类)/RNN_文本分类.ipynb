# %%
import torch
import torchtext
import torch.nn as nn
import torch.nn.functional as F
from torchtext.vocab import GloVe
from torchtext.legacy.data import Field

# %% [raw]
# TORCHTEXT.DATASETS
#
# 所有数据集都是的子类torchtext.data.Dataset，它们继承自torch.utils.data.Dataset，
#
# 并且具有split和 iters实现的方法。

# %%
TEXT = Field(lower=True, fix_length=200, batch_first=False)
LABEL = Field(sequential=False)
# make splits for data
train, test = torchtext.legacy.datasets.IMDB.splits(TEXT, LABEL)

# %%
train.fields
# Out:
# {'text': <torchtext.legacy.data.field.Field at 0x1b625f6da60>,
#  'label': <torchtext.legacy.data.field.Field at 0x1b625f6d8b0>}

# %%
# 构建词表 vocab
#TEXT.build_vocab(train, vectors=GloVe(name='6B', dim=300), 
#                 max_size=20000, min_freq=10)
TEXT.build_vocab(train, max_size=10000, min_freq=10, vectors=None)
LABEL.build_vocab(train)

# %%
TEXT.vocab.freqs
# Out:
# Counter({'bromwell': 8,
#          'high': 1707,
#          'is': 104171,
#          'a': 159953,
#          'cartoon': 386,
#          'comedy.': 388,
#          'it': 65505,
#          'ran': 218,
#          'at': 22731,
#          'the': 322198,
#          'same': 3770,
#          'time': 7945,
#          'as': 45102,
#          'some': 15280,
#          'other': 8229,
#          'programs': 42,
#          'about': 16486,
#          'school': 1140,
#          'life,': 715,
#          'such': 4812,
#          '"teachers".': 2,
#          'my': 11766,
#          '35': 55,
#          'years': 3335,
#          'in': 90527,
#          'teaching': 73,
#          'profession': 43,
#          'lead': 1120,
#          'me': 7722,
#          'to': 133967,
#          'believe': 2310,
#          'that': 66292,
#          "high's": 1,
#          'satire': 182,
#          'much': 8739,
#          'closer': 184,
#          'reality': 631,
#          'than': 9807,
#          'scramble': 5,
#          'survive': 180,
#          'financially,': 3,
#          'insightful': 50,
#          'students': 264,
#          'who': 19407,
#          'can': 10797,
#          'see': 10410,
#          'right': 2366,
#          'through': 4455,
#          'their': 11317,
#          'pathetic': 294,
#          "teachers'": 1,
#          'pomp,': 3,
#          'pettiness': 2,
#          'of': 144462,
#          'whole': 2896,
#          'situation,': 78,
#          'all': 19740,
#          'remind': 156,
#          'schools': 48,
#          'i': 70480,
#          'knew': 861,
#          'and': 158572,
#          'students.': 42,
#          'when': 13609,
#          'saw': 3031,
#          'episode': 1159,
#          'which': 10898,
#          'student': 291,
#          'repeatedly': 97,
#          'tried': 723,
#          'burn': 102,
#          'down': 2875,
#          'school,': 153,
#          'immediately': 381,
#          'recalled': 16,
#          '.........': 5,
#          '..........': 3,
#          'high.': 51,
#          'classic': 1317,
#          'line:': 75,
#          'inspector:': 1,
#          "i'm": 4174,
#          'here': 3055,
#          'sack': 29,
#          'one': 22480,
#          'your': 5600,
#          'teachers.': 7,
#          'student:': 1,
#          'welcome': 137,
#          'expect': 993,
#          'many': 6388,
#          'adults': 244,
#          'age': 698,
#          'think': 6773,
#          'far': 2582,
#          'fetched.': 7,
#          'what': 14055,
#          'pity': 158,
#          "isn't!": 3,
#          'homelessness': 3,
#          '(or': 613,
#          'houselessness': 1,
#          'george': 713,
#          'carlin': 8,
#          'stated)': 1,
#          'has': 16570,
#          'been': 9074,
#          'an': 21240,
#          'issue': 212,
#          'for': 42843,
#          'but': 39764,
#          'never': 6319,
#          'plan': 319,
#          'help': 1664,
#          'those': 4545,
#          'on': 31619,
#          'street': 429,
#          'were': 10528,
#          'once': 1885,
#          'considered': 458,
#          'human': 1374,
#          'did': 5514,
#          'everything': 1936,
#          'from': 19934,
#          'going': 3828,
#          'work,': 478,
#          'or': 16769,
#          'vote': 177,
#          'matter.': 120,
#          'most': 8477,
#          'people': 7676,
#          'homeless': 122,
#          'just': 17309,
#          'lost': 1266,
#          'cause': 394,
#          'while': 4686,
#          'worrying': 36,
#          'things': 3123,
#          'racism,': 29,
#          'war': 1322,
#          'iraq,': 14,
#          'pressuring': 5,
#          'kids': 1343,
#          'succeed,': 9,
#          'technology,': 42,
#          'elections,': 2,
#          'inflation,': 2,
#          'if': 15189,
#          "they'll": 116,
#          'be': 25691,
#          'next': 1429,
#          'end': 3547,
#          'up': 10776,
#          'streets.<br': 6,
#          '/><br': 50935,
#          '/>but': 774,
#          'you': 27564,
#          'given': 1726,
#          'bet': 201,
#          'live': 1276,
#          'streets': 178,
#          'month': 93,
#          'without': 3145,
#          'luxuries': 3,
#          'had': 11042,
#          'home,': 207,
#          'entertainment': 473,
#          'sets,': 129,
#          'bathroom,': 12,
#          'pictures': 318,
#          'wall,': 38,
#          'computer,': 16,
#          'treasure': 122,
#          "it's": 15970,
#          'like': 18779,
#          'homeless?': 1,
#          'goddard': 4,
#          "bolt's": 1,
#          'lesson.<br': 4,
#          '/>mel': 1,
#          'brooks': 108,
#          '(who': 525,
#          'directs)': 3,
#          'stars': 1100,
#          'bolt': 21,
#          'plays': 2133,
#          'rich': 487,
#          'man': 3872,
#          'world': 2507,
#          'until': 1724,
#          'deciding': 52,
#          'make': 7590,
#          'with': 42729,
#          'sissy': 56,
#          'rival': 121,
#          '(jeffery': 1,
#          'tambor)': 1,
#          'he': 26177,
#          'thirty': 110,
#          'days': 726,
#          'luxuries;': 1,
#          'succeeds,': 8,
#          'do': 7904,
#          'wants': 1227,
#          'future': 589,
#          'project': 309,
#          'making': 2426,
#          'more': 13170,
#          'buildings.': 9,
#          "bet's": 2,
#          'where': 6056,
#          'thrown': 397,
#          'bracelet': 7,
#          'his': 29059,
#          'leg': 67,
#          'monitor': 18,
#          'every': 3885,
#          'move': 623,
#          "can't": 3442,
#          'step': 297,
#          'off': 4519,
#          'sidewalk.': 4,
#          "he's": 2790,
#          'nickname': 14,
#          'pepto': 2,
#          'by': 21976,
#          'vagrant': 1,
#          'after': 7118,
#          'written': 1165,
#          'forehead': 13,
#          'meets': 651,
#          'characters': 5263,
#          'including': 842,
#          'woman': 2032,
#          'name': 1186,
#          'molly': 73,
#          '(lesley': 2,
#          'ann': 209,
#          'warren)': 3,
#          'ex-dancer': 2,
#          'got': 3503,
#          'divorce': 59,
#          'before': 3430,
#          'losing': 210,
#          'her': 16540,
#          'pals': 27,
#          'sailor': 35,
#          '(howard': 4,
#          'morris)': 1,
#          'fumes': 4,
#          '(teddy': 1,
#          'wilson)': 12,
#          'are': 28743,
#          'already': 1196,
#          'used': 1745,
#          'streets.': 23,
#          "they're": 1208,
#          'survivors.': 14,
#          "isn't.": 79,
#          'not': 28597,
#          'reaching': 86,
#          'mutual': 61,
#          'agreements': 3,
#          'being': 6390,
#          'fight': 977,
#          'flight,': 11,
#          'kill': 1059,
#          'killed.<br': 14,
#          '/>while': 251,
#          'love': 5326,
#          'connection': 222,
#          'between': 3260,
#          "wasn't": 2206,
#          'necessary': 229,
#          'plot,': 729,
#          'found': 2494,
#          '"life': 26,
#          'stinks"': 2,
#          'mel': 108,
#          "brooks'": 21,
#          'observant': 11,
#          'films': 4828,
#          'prior': 168,
#          'comedy,': 471,
#          'shows': 2002,
#          'tender': 79,
#          'side': 889,
#          'compared': 509,
#          'slapstick': 128,
#          'work': 2917,
#          'blazing': 29,
#          'saddles,': 5,
#          'young': 3293,
#          'frankenstein,': 10,
#          'spaceballs': 2,
#          'matter,': 113,
#          'show': 4623,
#          'having': 2433,
#          'something': 4387,
#          'valuable': 90,
#          'day': 1536,
#          'hand': 651,
#          'stupid': 1139,
#          'they': 20624,
#          "don't": 7879,
#          'know': 5336,
#          'money.': 286,
#          'maybe': 1990,
#          'should': 4842,
#          'give': 3300,
#          'instead': 1571,
#          'using': 767,
#          'monopoly': 8,
#          'money.<br': 39,
#          '/>or': 27,
#          'this': 69714,
#          'film': 27777,
#          'will': 8926,
#          'inspire': 55,
#          'others.': 211,
#          'brilliant': 839,
#          'over-acting': 20,
#          'lesley': 7,
#          'warren.': 2,
#          'best': 5426,
#          'dramatic': 561,
#          'hobo': 5,
#          'lady': 619,
#          'have': 27344,
#          'ever': 5077,
#          'seen,': 305,
#          'scenes': 3874,
#          'clothes': 214,
#          'warehouse': 30,
#          'second': 1625,
#          'none.': 55,
#          'corn': 36,
#          'face': 1134,
#          'classic,': 127,
#          'good': 11926,
#          'anything': 2475,
#          'saddles.': 4,
#          'take': 3336,
#          'lawyers': 25,
#          'also': 8007,
#          'superb.': 88,
#          'accused': 110,
#          'turncoat,': 1,
#          'selling': 103,
#          'out': 14510,
#          'boss,': 71,
#          'dishonest': 15,
#          'lawyer': 148,
#          'shrugs': 5,
#          'indifferently': 3,
#          '"i\'m': 126,
#          'lawyer"': 1,
#          'says.': 26,
#          'three': 2016,
#          'funny': 2502,
#          'words.': 66,
#          'jeffrey': 95,
#          'tambor,': 3,
#          'favorite': 1119,
#          'later': 1455,
#          'larry': 137,
#          'sanders': 39,
#          'show,': 498,
#          'fantastic': 566,
#          'too': 6142,
#          'mad': 358,
#          'millionaire': 46,
#          'crush': 87,
#          'ghetto.': 9,
#          'character': 5260,
#          'malevolent': 26,
#          'usual.': 40,
#          'hospital': 232,
#          'scene,': 546,
#          'scene': 4060,
#          'invade': 12,
#          'demolition': 13,
#          'site,': 42,
#          'all-time': 98,
#          'classics.': 30,
#          'look': 3691,
#          'legs': 102,
#          'two': 6210,
#          'big': 3083,
#          'diggers': 11,
#          'fighting': 491,
#          '(one': 149,
#          'bleeds).': 1,
#          'movie': 30887,
#          'gets': 3117,
#          'better': 4495,
#          'each': 2525,
#          '(which': 678,
#          'quite': 3662,
#          'often).': 4,
#          'easily': 805,
#          'underrated': 194,
#          'inn': 15,
#          'cannon.': 5,
#          'sure,': 336,
#          'its': 7963,
#          'flawed.': 11,
#          'does': 5495,
#          'realistic': 506,
#          'view': 663,
#          '(unlike,': 3,
#          'say,': 612,
#          'how': 8456,
#          'citizen': 76,
#          'kane': 53,
#          'gave': 1208,
#          'lounge': 11,
#          'singers,': 15,
#          'titanic': 93,
#          'italians': 21,
#          'idiots).': 2,
#          'jokes': 671,
#          'fall': 727,
#          'flat.': 83,
#          'still,': 331,
#          'very': 13633,
#          'lovable': 109,
#          'way': 5815,
#          'comedies': 290,
#          'not,': 380,
#          'pull': 332,
#          'story': 8743,
#          'traditionally': 20,
#          'reviled': 7,
#          'members': 437,
#          'society': 377,
#          'truly': 1689,
#          'impressive.': 66,
#          'fisher': 73,
#          'king,': 72,
#          'crap,': 84,
#          'either.': 351,
#          'only': 11566,
#          'complaint': 111,
#          'cast': 2883,
#          'someone': 2083,
#          'else': 1294,
#          '(i': 729,
#          'director': 3021,
#          'writer,': 95,
#          'so': 18099,
#          'lead).': 4,
#          'typical': 739,
#          'film.': 4490,
#          'was': 47024,
#          'less': 1655,
#          'movies': 5255,
#          'actually': 3911,
#          'plot': 4776,
#          'followable.': 1,
#          'leslie': 140,
#          'warren': 92,
#          'made': 7041,
#          'movie,': 3979,
#          'she': 12234,
#          'fantastic,': 74,
#          'under-rated': 14,
#          'actress.': 106,
#          'there': 13094,
#          'moments': 1124,
#          'could': 7594,
#          'fleshed': 46,
#          'bit': 2760,
#          'more,': 223,
#          'probably': 2724,
#          'cut': 782,
#          'room': 614,
#          'so,': 695,
#          'all,': 1473,
#          'worth': 2154,
#          'price': 203,
#          'rent': 623,
#          'it.': 5558,
#          'acting': 4747,
#          'overall,': 291,
#          'himself': 1527,
#          'job': 1632,
#          'characteristic': 43,
#          'speaking': 289,
#          'directly': 177,
#          'audience.': 294,
#          'again,': 842,
#          'actor': 1570,
#          '"fume"': 1,
#          '"sailor"': 1,
#          'both': 3133,
#          'played': 2238,
#          'parts': 906,
#          'well.': 1062,
#          "isn't": 3000,
#          'comedic': 289,
#          'robin': 177,
#          'williams,': 41,
#          'nor': 666,
#          'quirky/insane': 1,
#          'williams': 219,
#          'recent': 500,
#          'thriller': 457,
#          'fame.': 33,
#          'hybrid': 45,
#          'drama': 806,
#          'over-dramatization,': 2,
#          'mixed': 255,
#          "robin's": 6,
#          'new': 3994,
#          'thriller.': 120,
#          'thriller,': 127,
#          'per': 125,
#          'se.': 9,
#          'mystery/suspense': 1,
#          'vehicle': 185,
#          'attempts': 554,
#          'locate': 36,
#          'sick': 344,
#          'boy': 988,
#          'keeper.<br': 1,
#          '/>also': 105,
#          'starring': 439,
#          'sandra': 72,
#          'oh': 650,
#          'rory': 17,
#          'culkin,': 4,
#          'suspense': 418,
#          'pretty': 3520,
#          'news': 251,
#          'report,': 14,
#          "william's": 11,
#          'close': 948,
#          'achieving': 32,
#          'goal.<br': 4,
#          '/>i': 3735,
#          'must': 2970,
#          'say': 4392,
#          'highly': 1056,
#          'entertained,': 31,
#          'though': 3141,
#          'fails': 520,
#          'teach,': 2,
#          'guide,': 14,
#          'inspect,': 1,
#          'amuse.': 2,
#          'felt': 1479,
#          'watching': 4117,
#          'guy': 2286,
#          '(williams),': 1,
#          'performing': 118,
#          'actions,': 33,
#          'third': 613,
#          'person': 1188,
#          'perspective.': 40,
#          'words,': 168,
#          'real,': 127,
#          'able': 1230,
#          'subscribe': 11,
#          'premise': 541,
#          'story.<br': 185,
#          '/>all': 415,
#          'watch,': 276,
#          'definitely': 1517,
#          'friday/saturday': 2,
#          'night': 1377,
#          'fare.<br': 7,
#          '/>it': 971,
#          'rates': 70,
#          '7.7/10': 1,
#          'from...<br': 20,
#          '/>the': 7409,
#          'fiend': 33,
#          ':.': 21,
#          'yes': 289,
#          'art...': 3,
#          'successfully': 131,
#          'slow': 743,
#          'paced': 119,
#          'thriller.<br': 16,
#          'unfolds': 65,
#          'nice': 1719,
#          'volumes': 30,
#          'even': 12010,
#          'notice': 292,
#          'happening.<br': 20,
#          '/>fine': 1,
#          'performance': 2133,
#          'williams.': 20,
#          'sexuality': 88,
#          'angles': 132,
#          'seem': 2142,
#          'unnecessary': 218,
#          'affect': 89,
#          'enjoy': 1546,
#          'however,': 2346,
#          'core': 137,
#          'engaging.': 38,
#          "doesn't": 4424,
#          'rush': 106,
#          'onto': 323,
#          'still': 5053,
#          'grips': 32,
#          'enough': 2718,
#          'keep': 1572,
#          'wondering.': 4,
#          'direction': 898,
#          'good.': 1065,
#          'use': 1711,
#          'lights': 133,
#          'achieve': 147,
#          'desired': 38,
#          'affects': 57,
#          'unexpectedness': 2,
#          'good.<br': 125,
#          '/>very': 64,
#          '1': 653,
#          'watch': 5709,
#          'looking': 2110,
#          'lay': 84,
#          'back': 4086,
#          'hear': 694,
#          'thrilling': 114,
#          'short': 1358,
#          'story!': 29,
#          '"critically': 1,
#          'acclaimed': 64,
#          'psychological': 244,
#          'based': 1260,
#          'true': 1790,
#          'events,': 89,
#          'gabriel': 71,
#          '(robin': 9,
#          'williams),': 3,
#          'celebrated': 51,
#          'writer': 590,
#          'late-night': 25,
#          'talk': 704,
#          'host,': 13,
#          'becomes': 1367,
#          'captivated': 40,
#          'harrowing': 41,
#          'listener': 23,
#          'adoptive': 8,
#          'mother': 971,
#          '(toni': 7,
#          'collette).': 2,
#          'troubling': 18,
#          'questions': 367,
#          'arise': 18,
#          "boy's": 64,
#          '(story),': 2,
#          'finds': 941,
#          'drawn': 347,
#          'into': 8990,
#          'widening': 5,
#          'mystery': 553,
#          'hides': 61,
#          'deadly': 176,
#          'secret': 478,
#          '"': 342,
#          'according': 260,
#          "film's": 1031,
#          'official': 84,
#          'synopsis.<br': 12,
#          '/>you': 212,
#          'really': 11065,
#          'stop': 880,
#          'reading': 625,
#          'these': 5233,
#          'comments,': 84,
#          'now...<br': 3,
#          '"how': 97,
#          'lose': 309,
#          'leg?"': 1,
#          'ending,': 228,
#          'ms.': 279,
#          'collette': 30,
#          'planning': 110,
#          'chopped': 55,
#          'off,': 389,
#          'sent': 389,
#          '"deleted': 2,
#          'scenes"': 11,
#          'land.': 40,
#          'overkill.': 7,
#          'nature': 519,
#          'physical': 290,
#          'mental': 294,
#          'ailments': 4,
#          'obvious,': 57,
#          'mr.': 986,
#          'returns': 254,
#          'york.': 73,
#          'possibly,': 11,
#          'blindness': 10,
#          'question': 481,
#          '-': 9355,
#          'revelation': 96,
#          'certain': 737,
#          'either': 1182,
#          '"highway"': 1,
#          '"video': 6,
#          'tape"': 2,
#          'scenes.': 460,
#          'would': 12027,
#          'benefit': 92,
#          're-editing': 6,
#          '"director\'s': 5,
#          'cut"?': 1,
#          '<br': 5828,
#          '/>williams': 6,
#          'bobby': 104,
#          'cannavale': 4,
#          '(as': 699,
#          'jess)': 1,
#          'seem,': 15,
#          'initially,': 23,
#          'believable': 449,
#          'couple.': 47,
#          'establishing': 52,
#          'relationship': 797,
#          'might': 2851,
#          'helped': 305,
#          'set': 2027,
#          'stage.': 60,
#          'otherwise,': 135,
#          'exemplary.': 3,
#          'offers': 331,
#          'exceptionally': 86,
#          'strong': 917,
#          'characterization,': 22,
#          '"gay': 12,
#          'impersonation".': 1,
#          'anna),': 1,
#          'joe': 559,
#          'morton': 16,
#          'ashe),': 1,
#          'culkin': 22,
#          '(pete': 2,
#          'logand)': 1,
#          'perfect.<br': 19,
#          '/>best': 40,
#          "collette's": 5,
#          '"donna"': 2,
#          'belongs': 126,
#          'creepy': 468,
#          'hall': 138,
#          'correct': 148,
#          'saying': 807,
#          'be,': 277,
#          '"you': 150,
#          'know,': 379,
#          '\'psycho\'."': 1,
#          'several': 1393,
#          'organizations': 8,
#          'giving': 820,
#          'awards': 165,
#          'seemed': 1351,
#          'reach': 228,
#          'women,': 163,
#          'due': 853,
#          'slighter': 2,
#          'dispersion': 1,
#          'roles;': 10,
#          'certainly,': 29,
#          'noticed': 236,
#          'award': 307,
#          'consideration.': 8,
#          'and,': 1115,
#          'patrick': 170,
#          'stettner': 3,
#          'evokes': 44,
#          'hitchcock': 113,
#          'makes': 4150,
#          'getting': 1582,
#          'sandwich': 7,
#          'vending': 3,
#          'machine': 193,
#          'suspenseful.<br': 1,
#          '/>finally,': 84,
#          'writers': 523,
#          'stettner,': 2,
#          'armistead': 5,
#          'maupin,': 1,
#          'terry': 80,
#          'anderson': 131,
#          'deserve': 264,
#          'gratitude': 17,
#          'flight': 124,
#          'attendants': 4,
#          'everywhere.<br': 9,
#          '/>*******': 6,
#          '(1/21/06)': 1,
#          '~': 65,
#          'toni': 48,
#          'collette,': 9,
#          'oh,': 352,
#          '(2006)': 10,
#          '**1/2': 4,
#          'cannavale,': 1,
#          'morton,': 4,
#          'john': 1887,
#          'cullum,': 1,
#          'lisa': 132,
#          'emery,': 1,
#          'becky': 19,
#          'baker.': 11,
#          '(dir:': 1,
#          'stettner)': 2,
#          '/>hitchcockian': 1,
#          'suspenser': 2,
#          'gives': 1562,
#          'stand-out': 20,
#          'low-key': 50,
#          'performance.<br': 53,
#          '/>what': 490,
#          'celebrities': 30,
#          'fans?': 6,
#          'near': 735,
#          'paranoia': 50,
#          'associates': 24,
#          'why': 4370,
#          'almost': 3019,
#          'norm?': 2,
#          '/>in': 974,
#          'latest': 195,
#          'derange': 2,
#          'fan': 1432,
#          'scenario,': 25,
#          'events': 710,
#          'no': 11273,
#          'less,': 52,
#          'talk-radio': 1,
#          'personality': 224,
#          'named': 761,
#          'one,': 819,
#          'reads': 88,
#          'stories': 850,
#          'penned': 41,
#          'over': 5027,
#          'airwaves': 8,
#          'accumulated': 5,
#          'interesting': 2364,
#          'form': 576,
#          'pete': 58,
#          'logand': 1,
#          '(culkin)': 1,
#          'submitted': 19,
#          'manuscript': 14,
#          'travails': 6,
#          'troubled': 129,
#          'youth': 168,
#          "one's": 246,
#          'editor': 81,
#          'ashe': 1,
#          '(morton)': 1,
#          'read': 1774,
#          'himself.': 275,
#          '/>no': 103,
#          'naturally': 141,
#          'disturbed': 80,
#          'ultimately': 427,
#          'intrigued': 104,
#          'nightmarish': 38,
#          'existence': 146,
#          'abducted': 25,
#          'sexually': 120,
#          'abused': 68,
#          'finally': 1193,
#          'rescued': 46,
#          'nurse': 82,
#          'donna': 73,
#          '(collette': 1,
#          'excellent': 1611,
#          'performance)': 22,
#          'adopted': 65,
#          'correspondence': 9,
#          'reveals': 179,
#          'dying': 247,
#          'aids.': 12,
#          'meet': 586,
#          'fans': 1003,
#          'suddenly': 466,
#          'doubt': 622,
#          'possibly': 658,
#          'devious': 21,
#          'ulterior': 12,
#          'motives': 74,
#          'seed': 60,
#          'planted': 30,
#          'estranged': 53,
#          'lover': 212,
#          'jess': 51,
#          '(cannavale)': 1,
#          'whose': 940,
#          'sudden': 207,
#          'departure': 59,
#          'york': 550,
#          'city': 732,
#          'apartment': 225,
#          'emotional': 616,
#          'tailspin': 3,
#          'now': 3006,
#          'grown': 203,
#          'tempest': 8,
#          'teacup': 4,
#          'decides': 542,
#          'investigating': 60,
#          "pete's": 13,
#          'backgrounds': 63,
#          'discovering': 73,
#          'truths': 32,
#          "didn't": 4147,
#          'anticipate.<br': 1,
#          '/>written': 13,
#          'maupin': 2,
#          'co-wrote': 29,
#          'screenplay': 479,
#          'former': 478,
#          'novice': 24,
#          "fan's": 8,
#          'hoax': 6,
#          'hitchcockian': 12,
#          'run': 940,
#          'full': 1561,
#          'tilt': 7,
#          'any': 7507,
#          'old': 3589,
#          'fashioned': 71,
#          'pot-boiler': 4,
#          'does.': 192,
#          'helps': 334,
#          'stand-out,': 2,
#          'conflicted': 32,
#          'good-hearted': 22,
#          'genuinely': 249,
#          'number': 918,
#          'fact': 2555,
#          'real': 4026,
#          'him': 6385,
#          '(the': 1390,
#          'thing': 3514,
#          'escaped': 102,
#          'own': 2926,
#          'reality)': 4,
#          'unsettling': 73,
#          'dreadful': 167,
#          'trait': 19,
#          'leave': 975,
#          'unmentioned': 2,
#          'underlines': 14,
#          'desperation': 68,
#          'rattle': 7,
#          'core.<br': 5,
#          '/>however': 38,
#          'runs': 472,
#          'gas': 137,
#          'eventually': 628,
#          'repetitive': 81,
#          'predictable': 504,
#          'despite': 1195,
#          'finely': 33,
#          'directed': 980,
#          'piece': 1330,
#          'hoodwink': 2,
#          'pays': 102,
#          'listen': 284,
#          'inner': 185,
#          'voice:': 2,
#          'careful': 69,
#          'hope': 1292,
#          'for.': 275,
#          'god': 641,
#          'bless': 34,
#          'him,': 719,
#          'constantly': 386,
#          'shooting': 388,
#          'foot': 169,
#          'lately': 49,
#          'dumb': 437,
#          'done': 2347,
#          'decade': 161,
#          '(with': 305,
#          'perhaps': 1407,
#          'exception': 264,
#          '"death': 35,
#          'smoochy",': 1,
#          'bombed': 31,
#          'came': 1635,
#          'cult': 379,
#          'classic).': 1,
#          'dramas': 82,
#          'especially': 2166,
#          '"insomnia"': 2,
#          ...})

# %%
TEXT.vocab.vectors

# %%
BATCHSIZE = 256

# %%
# make iterator for splits
train_iter, test_iter = torchtext.legacy.data.BucketIterator.splits(
                                      (train, test), batch_size=BATCHSIZE)

# %%
b = next(iter(train_iter))

# %%
b.text.shape
# Out:
# torch.Size([200, 256])

# %%
embeding_dim = 100
hidden_size = 200

# %% [raw]
# batch_size * 200 * 100 ---> seg_length * batch * embeding_dim

# %%
class RNN_Encoder(nn.Module):
    def __init__(self, input_dim, hidden_size):
        super(RNN_Encoder, self).__init__()
        self.rnn = nn.RNNCell(input_dim, hidden_size)
    def forward(self, inputs):
        bz = inputs.shape[1]
        ht = torch.zeros((bz, hidden_size))
        for word in inputs:
            ht = self.rnn(word, ht)
        return ht

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.em = nn.Embedding(20002, embeding_dim)   # 200*batch*100
        self.rnn = RNN_Encoder(embeding_dim, hidden_size)     # batch*300
        self.fc1 = nn.Linear(hidden_size, 256)
        self.fc2 = nn.Linear(256, 3)

    def forward(self, x):
        x = self.em(x)
        x = self.rnn(x)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model = Net()

# %%
if torch.cuda.is_available():
    model.to('cuda')

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %%
def fit(epoch, model, trainloader, testloader):
    correct = 0
    total = 0
    running_loss = 0
    
    model.train()
    for b in trainloader:
        x, y = b.text, b.label
        if torch.cuda.is_available():
            x, y = x.to('cuda'), y.to('cuda')
        y_pred = model(x)
        loss = loss_fn(y_pred, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            y_pred = torch.argmax(y_pred, dim=1)
            correct += (y_pred == y).sum().item()
            total += y.size(0)
            running_loss += loss.item()
#    exp_lr_scheduler.step()
    epoch_loss = running_loss / len(trainloader.dataset)
    epoch_acc = correct / total
        
        
    test_correct = 0
    test_total = 0
    test_running_loss = 0 
    
    model.eval()
    with torch.no_grad():
        for b in testloader:
            x, y = b.text, b.label
            if torch.cuda.is_available():
                x, y = x.to('cuda'), y.to('cuda')
            y_pred = model(x)
            loss = loss_fn(y_pred, y)
            y_pred = torch.argmax(y_pred, dim=1)
            test_correct += (y_pred == y).sum().item()
            test_total += y.size(0)
            test_running_loss += loss.item()
    
    epoch_test_loss = test_running_loss / len(testloader.dataset)
    epoch_test_acc = test_correct / test_total
    
        
    print('epoch: ', epoch, 
          'loss： ', round(epoch_loss, 3),
          'accuracy:', round(epoch_acc, 3),
          'test_loss： ', round(epoch_test_loss, 3),
          'test_accuracy:', round(epoch_test_acc, 3)
             )
        
    return epoch_loss, epoch_acc, epoch_test_loss, epoch_test_acc

# %%
epochs = 50

# %%
train_loss = []
train_acc = []
test_loss = []
test_acc = []

for epoch in range(epochs):
    epoch_loss, epoch_acc, epoch_test_loss, epoch_test_acc = fit(epoch,
                                                                 model,
                                                                 train_iter,
                                                                 test_iter)
    train_loss.append(epoch_loss)
    train_acc.append(epoch_acc)
    test_loss.append(epoch_test_loss)
    test_acc.append(epoch_test_acc)
# Out:
# epoch:  0 loss：  0.003 accuracy: 0.526 test_loss：  0.003 test_accuracy: 0.51
# epoch:  1 loss：  0.003 accuracy: 0.528 test_loss：  0.003 test_accuracy: 0.504
# epoch:  2 loss：  0.003 accuracy: 0.531 test_loss：  0.003 test_accuracy: 0.505
# epoch:  3 loss：  0.003 accuracy: 0.532 test_loss：  0.003 test_accuracy: 0.504
# epoch:  4 loss：  0.003 accuracy: 0.542 test_loss：  0.003 test_accuracy: 0.506
# epoch:  5 loss：  0.003 accuracy: 0.541 test_loss：  0.003 test_accuracy: 0.506
# epoch:  6 loss：  0.003 accuracy: 0.542 test_loss：  0.003 test_accuracy: 0.513
# epoch:  7 loss：  0.003 accuracy: 0.548 test_loss：  0.003 test_accuracy: 0.509
# epoch:  8 loss：  0.003 accuracy: 0.551 test_loss：  0.003 test_accuracy: 0.511
# epoch:  9 loss：  0.003 accuracy: 0.557 test_loss：  0.003 test_accuracy: 0.519
# epoch:  10 loss：  0.003 accuracy: 0.567 test_loss：  0.003 test_accuracy: 0.529
# epoch:  11 loss：  0.003 accuracy: 0.569 test_loss：  0.003 test_accuracy: 0.518
# epoch:  12 loss：  0.003 accuracy: 0.574 test_loss：  0.003 test_accuracy: 0.536
# epoch:  13 loss：  0.003 accuracy: 0.585 test_loss：  0.003 test_accuracy: 0.53
# epoch:  14 loss：  0.003 accuracy: 0.587 test_loss：  0.003 test_accuracy: 0.537
# epoch:  15 loss：  0.003 accuracy: 0.591 test_loss：  0.003 test_accuracy: 0.547
# epoch:  16 loss：  0.003 accuracy: 0.594 test_loss：  0.003 test_accuracy: 0.541
# epoch:  17 loss：  0.002 accuracy: 0.605 test_loss：  0.003 test_accuracy: 0.556
# epoch:  18 loss：  0.002 accuracy: 0.603 test_loss：  0.003 test_accuracy: 0.549
# epoch:  19 loss：  0.002 accuracy: 0.606 test_loss：  0.003 test_accuracy: 0.542
# epoch:  20 loss：  0.002 accuracy: 0.614 test_loss：  0.003 test_accuracy: 0.543
# epoch:  21 loss：  0.002 accuracy: 0.618 test_loss：  0.003 test_accuracy: 0.554
# epoch:  22 loss：  0.002 accuracy: 0.625 test_loss：  0.003 test_accuracy: 0.565
# epoch:  23 loss：  0.002 accuracy: 0.627 test_loss：  0.003 test_accuracy: 0.554
# epoch:  24 loss：  0.002 accuracy: 0.623 test_loss：  0.003 test_accuracy: 0.555
# epoch:  25 loss：  0.002 accuracy: 0.631 test_loss：  0.003 test_accuracy: 0.565
# epoch:  26 loss：  0.002 accuracy: 0.639 test_loss：  0.003 test_accuracy: 0.544
# epoch:  27 loss：  0.002 accuracy: 0.623 test_loss：  0.003 test_accuracy: 0.548
# epoch:  28 loss：  0.002 accuracy: 0.634 test_loss：  0.003 test_accuracy: 0.559
# epoch:  29 loss：  0.002 accuracy: 0.635 test_loss：  0.003 test_accuracy: 0.571
# epoch:  30 loss：  0.002 accuracy: 0.642 test_loss：  0.003 test_accuracy: 0.563
# epoch:  31 loss：  0.002 accuracy: 0.662 test_loss：  0.003 test_accuracy: 0.534
# epoch:  32 loss：  0.002 accuracy: 0.625 test_loss：  0.003 test_accuracy: 0.556
# epoch:  33 loss：  0.002 accuracy: 0.633 test_loss：  0.003 test_accuracy: 0.559
# epoch:  34 loss：  0.002 accuracy: 0.64 test_loss：  0.003 test_accuracy: 0.567
# epoch:  35 loss：  0.002 accuracy: 0.641 test_loss：  0.003 test_accuracy: 0.549
# epoch:  36 loss：  0.002 accuracy: 0.642 test_loss：  0.003 test_accuracy: 0.574
# epoch:  37 loss：  0.002 accuracy: 0.642 test_loss：  0.003 test_accuracy: 0.572
# epoch:  38 loss：  0.002 accuracy: 0.651 test_loss：  0.003 test_accuracy: 0.576
# epoch:  39 loss：  0.002 accuracy: 0.662 test_loss：  0.003 test_accuracy: 0.69
# epoch:  40 loss：  0.002 accuracy: 0.689 test_loss：  0.003 test_accuracy: 0.507
# epoch:  41 loss：  0.002 accuracy: 0.605 test_loss：  0.003 test_accuracy: 0.508
# epoch:  42 loss：  0.002 accuracy: 0.635 test_loss：  0.003 test_accuracy: 0.586
# epoch:  43 loss：  0.002 accuracy: 0.701 test_loss：  0.003 test_accuracy: 0.529
# epoch:  44 loss：  0.002 accuracy: 0.647 test_loss：  0.003 test_accuracy: 0.563
# epoch:  45 loss：  0.002 accuracy: 0.656 test_loss：  0.003 test_accuracy: 0.557
# epoch:  46 loss：  0.002 accuracy: 0.657 test_loss：  0.003 test_accuracy: 0.564
# epoch:  47 loss：  0.002 accuracy: 0.658 test_loss：  0.003 test_accuracy: 0.553
# epoch:  48 loss：  0.002 accuracy: 0.666 test_loss：  0.003 test_accuracy: 0.579
# epoch:  49 loss：  0.002 accuracy: 0.699 test_loss：  0.003 test_accuracy: 0.508
